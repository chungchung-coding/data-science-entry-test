# %% [markdown]
# <a href="https://colab.research.google.com/github/chungchung-coding/data-science-entry-test/blob/main/Q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def string_reverse(s):

    if not isinstance(s, str):
      return -1

    return s[::-1]

print(string_reverse("Hello World"))

print(string_reverse("Python"))
# Out:
# dlroW olleH
# nohtyP
